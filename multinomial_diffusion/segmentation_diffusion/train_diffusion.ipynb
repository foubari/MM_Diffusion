# %%
# Out:
# python3: can't open file '/content/train.py': [Errno 2] No such file or directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.environ['PYTHONPATH'] = '/drive/MyDrive/MM_Diffusion/multinomial_diffusion:/drive/MyDrive/MM_Diffusion/multinomial_diffusion/diffusion_utils'

# %%
pip install comet_ml
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 710.6/710.6 kB 21.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 980.3/980.3 kB 49.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 95.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 14.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: python-box
#     Found existing installation: python-box 7.3.0
#     Uninstalling python-box-7.3.0:
#       Successfully uninstalled python-box-7.3.0
# ...

# %%
# !export COMET_PROJECT_NAME="categorical-diffusion"

# %%
from google.colab import userdata
# !export PYTHONPATH=:drive/MyDrive/MM_Diffusion/multinomial_diffusion:drive/MyDrive/MM_Diffusion/multinomial_diffusion/diffusion_utils

# %%
# !pip install lpips
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 2.8 MB/s eta 0:00:00
# ...

# %%
! python drive/MyDrive/MM_Diffusion/multinomial_diffusion/segmentation_diffusion/train.py --eval_every 1 --check_every 1 --epochs 50 --log_home drive/MyDrive/MM_Diffusion/results --diffusion_steps 4000 --dataset cityscapes_fine --batch_size 250 --dp_rate 0.1 --augmentation shift --lr 0.0001 --warmup 5 --batch_size 250 --data_root drive/MyDrive/MM_Diffusion --device cuda:0
# Out:
# 2024-12-31 16:34:06.962039: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-31 16:34:06.982909: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-31 16:34:06.989414: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-31 16:34:07.003510: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
! python drive/MyDrive/MM_Diffusion/multinomial_diffusion/segmentation_diffusion/eval_sample_start.py --model /var/scratch/ehoogebo/cityscapes_fine/multinomial_diffusion/multistep/2024-12-31_14-21-57
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Data shape: (1, 32, 64)
# ...
